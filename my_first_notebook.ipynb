# %% [markdown]
# Software : It is a type of program wich was totally build by code. Now a days we multiple applications on our day to day work for example Micro Soft365 here we have applications to boost our work in simple terms we can say that an application which was desinged to use
# Example : Micro Soft , Windows and so...
#
# Hardware : Hardware is defined as a physical components that are actually bulid inside the computer they perform the work which assigned by software
#
# Example : Mother board ,
# CPU , Keyboard .....
